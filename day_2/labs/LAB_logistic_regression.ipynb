# %%
# Import necessary libraries
import pandas as pd
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.inspection import DecisionBoundaryDisplay

# %%
# Load the iris dataset
dataset = pd.read_csv("data/iris_dataset.csv")

# Select the features and prediction columns
X = dataset[["petalLength", "petalWidth"]]
y = pd.factorize(dataset["species"])[0]

# View the first few rows of the dataset
dataset.head(5)
# Out:
#    petalLength  petalWidth          species
# 0          1.4         0.2      Iris-setosa
# 1          4.7         1.4  Iris-versicolor
# 2          1.4         0.2      Iris-setosa
# 3          3.7         1.0  Iris-versicolor
# 4          1.3         0.2      Iris-setosa

# %%
# Plot the data
plt.figure(figsize = (6, 4))
plt.scatter(X['petalLength'], X['petalWidth'], c = y, cmap = 'viridis')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Iris Data: Petal Length vs Petal Width')
plt.show()

# %%
# Create and train the Logistic Regression model on all data
model = LogisticRegression(max_iter = 10000)
model.fit(X, y)
# Out:
# LogisticRegression(max_iter=10000)

# %%
# Plot the data with the computed decision boundary
disp = DecisionBoundaryDisplay.from_estimator(
    model, X, cmap = 'viridis', alpha = 0.3, response_method = 'predict'
)
plt.scatter(X['petalLength'], X['petalWidth'], c = y, cmap = 'viridis')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Logistic Regression Decision Boundary (Iris)')
plt.show()
